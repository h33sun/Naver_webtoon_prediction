# %%
import numpy as np
import pandas as pd
import requests
import re
import time
import pickle
import datetime
import warnings

from bs4 import BeautifulSoup as bs

warnings.filterwarnings(action='ignore')

# %%
#네이버 도전웹툰 1~1000page의 모든 웹툰 제목(title), 링크(link), 평점(star)를 수집
def get_challenge_webtoon(category, page):
    url = 'https://comic.naver.com/genre/bestChallenge.nhn?m={}&page={}'.format(category, page)
    response = requests.get(url)
    webtoons = bs(response.content, 'html.parser')
    
    domain = 'https://comic.naver.com'
    for webtoon in webtoons.select('.challengeInfo'):
        table.append({
            
            'title' : webtoon.select('a')[0].text.strip(),
            'link' : domain + webtoon.select('a')[0].get('href'),
            'star' : webtoon.select_one('.star').get('title'),
            'category': category
        })

#link를 받아 에피소드의 개수를 체크함 (첫번째 url = 마지막 에피소드 url에 회차정보가 담겨 있음)       
def check_num_episode(title_link):
    response = requests.get(title_link)
    docs = bs(response.content, 'html.parser')
    last_episode_html = docs.select_one('.title > a').get('href')
    last_episode_date = docs.select_one('.num').text
#     likes = docs.select_one('em.u_cnt').text
    
    return last_episode_html[-4:], last_episode_date

# %%
url = 'https://comic.like.naver.com/likeIt/likeItContent.jsonp?_callback=window.__jindo2_callback.$2328&serviceId=COMIC&displayId=COMIC&contentsId=729593&lang=ko&viewType=like'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response
# Out:
# <Response [200]>

# %%
docs.select('div.detail > ul >li:nth-child(5) > div.u_likeit_module')[0]
# Out:
# <div class="u_likeit_module">
# </div>

# %%
# Out:
# []

# %%
table = []
categories = {'0': 'episode',
              '1': 'omnibus',
              '2': 'story',
              '3': 'daily',
              '4': 'comic',
              '5': 'fantasy',
              '6': 'action',
              '7': 'drama',
              '8': 'pure',
              '9': 'sensibility',
              '10': 'thrill',
              '11': 'historical',
              '12': 'sports',
             }

for i,category in categories.items():
    for page in range(1,2):
        get_challenge_webtoon(category,page)
        
result = pd.DataFrame(table)
result.star = result.star.apply(lambda x: float(x.replace('점','')))
result['title_id'] = result.link.apply(lambda x:x[-6:])
result.tail()
# Out:
#     category                                               link  star  \
# 307    story  https://comic.naver.com/bestChallenge/list.nhn...  9.87
# 308    story  https://comic.naver.com/bestChallenge/list.nhn...  9.59
# 309    story  https://comic.naver.com/bestChallenge/list.nhn...  9.89
# 310    story  https://comic.naver.com/bestChallenge/list.nhn...  9.86
# 311    story  https://comic.naver.com/bestChallenge/list.nhn...  9.78
#
#                              title title_id
# 307                          숲속의 성   541226
# 308                       공주님은 알바중   735988
# 309                     하나밖에 안 보여!   644886
# 310  Twins Love Story (트윈스 러브 스토리)   499692
# 311                             심연   695484

# %%
for page in range(1,2):#원래 range(1,1000)
    get_challenge_webtoon(page)

result = pd.DataFrame(table)
result.star = result.star.apply(lambda x: float(x.replace('점','')))
result['title_id'] = result.link.apply(lambda x:x[-6:])
result.tail()

# %%
#나중에함수
links = result.link
num = []
date = []
# likes = []


for i in range(len(links)):
    
    try:
        num.append(check_num_episode(links[i])[0])
        date.append(check_num_episode(links[i])[1])
#         likes.append(check_num_episode(links[i][2]))
        
    except AttributeError:
        num.append('0')
        date.append('2000.01.01')
#         likes.append('0')
        
    if i%30 == 0:
        print(str(i+1) +'/{}'.format(len(links)))
# Out:
# 1/312
# 31/312
# 61/312
# 91/312
# 121/312
# 151/312
# 181/312
# 211/312
# 241/312
# 271/312
# 301/312

# %%
result['num_episode'] = num
result['num_episode'] = result.num_episode.apply(lambda x: re.sub('[a-z=]','',x))
result['last_date'] = date
# result['likes'] = likes

now = datetime.datetime.now()
now = datetime.datetime.date(now)

result['last_date'] = result['last_date'].apply(lambda x: datetime.datetime.date(datetime.datetime.strptime(x, '%Y.%m.%d')))
result.head(100)

# result = result[['title_id','link','title','category', 'num_episode','last_date']]
# Out:
#    title_id                                               link  \
# 0    729593  https://comic.naver.com/bestChallenge/list.nhn...
# 1    696751  https://comic.naver.com/bestChallenge/list.nhn...
# 2    729599  https://comic.naver.com/bestChallenge/list.nhn...
# 3    663704  https://comic.naver.com/bestChallenge/list.nhn...
# 4    735601  https://comic.naver.com/bestChallenge/list.nhn...
# 5    736647  https://comic.naver.com/bestChallenge/list.nhn...
# 6    733288  https://comic.naver.com/bestChallenge/list.nhn...
# 7    734317  https://comic.naver.com/bestChallenge/list.nhn...
# 8    726814  https://comic.naver.com/bestChallenge/list.nhn...
# 9    734851  https://comic.naver.com/bestChallenge/list.nhn...
# 10   721750  https://comic.naver.com/bestChallenge/list.nhn...
# 11   730667  https://comic.naver.com/bestChallenge/list.nhn...
# 12   676977  https://comic.naver.com/bestChallenge/list.nhn...
# 13   640763  https://comic.naver.com/bestChallenge/list.nhn...
# 14   706431  https://comic.naver.com/bestChallenge/list.nhn...
# 15   325860  https://comic.naver.com/bestChallenge/list.nhn...
# 16   720291  https://comic.naver.com/bestChallenge/list.nhn...
# 17   715767  https://comic.naver.com/bestChallenge/list.nhn...
# 18   738355  https://comic.naver.com/bestChallenge/list.nhn...
# 19   730102  https://comic.naver.com/bestChallenge/list.nhn...
# 20   734947  https://comic.naver.com/bestChallenge/list.nhn...
# 21   681867  https://comic.naver.com/bestChallenge/list.nhn...
# 22   650217  https://comic.naver.com/bestChallenge/list.nhn...
# 23   726786  https://comic.naver.com/bestChallenge/list.nhn...
# 24   739004  https://comic.naver.com/bestChallenge/list.nhn...
# 25   736591  https://comic.naver.com/bestChallenge/list.nhn...
# 26   659485  https://comic.naver.com/bestChallenge/list.nhn...
# 27   696529  https://comic.naver.com/bestChallenge/list.nhn...
# 28   728672  https://comic.naver.com/bestChallenge/list.nhn...
# 29   734244  https://comic.naver.com/bestChallenge/list.nhn...
# ..      ...                                                ...
# 70   717229  https://comic.naver.com/bestChallenge/list.nhn...
# 71   725044  https://comic.naver.com/bestChallenge/list.nhn...
# 72   738187  https://comic.naver.com/bestChallenge/list.nhn...
# 73   729861  https://comic.naver.com/bestChallenge/list.nhn...
